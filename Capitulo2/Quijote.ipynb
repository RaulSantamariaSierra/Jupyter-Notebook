// %%
import org.apache.spark.sql.SparkSession
// Out:
// import org.apache.spark.sql.SparkSession

// %%
val sparkSession = SparkSession
    .builder()
    .master("local[*]")
    .appName("curso")
    .config("spark.some.config.option", "some-value")
    .getOrCreate()
// Out:
// sparkSession: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@76c90cef

// %%
val leer = sparkSession.read.text("el_quijote.txt")
// Out:
// leer: org.apache.spark.sql.DataFrame = [value: string]

// %%
leer.show()
// Out:
// +--------------------+
// |               value|
// +--------------------+
// |DON QUIJOTE DE LA...|
// |Miguel de Cervant...|
// |                    |
// |       PRIMERA PARTE|
// |CAPÍTULO 1: Que ...|
// |En un lugar de la...|
// |Tuvo muchas veces...|
// |En resolución, e...|
// |historia más cie...|
// |Decía él, que e...|
// |En efecto, remata...|
// |Imaginábase el p...|
// |linaje y patria, ...|
// |Limpias, pues, su...|
// |Capítulo 2: Que ...|
// |Hechas, pues, est...|
// |Estos pensamiento...|
// |Con estos iba ens...|
// |Autores hay que d...|
// |muertos de hambre...|
// +--------------------+
// only showing top 20 rows

// %%
leer.show(10, false)
// Out:
// +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// ...

// %%
println(leer.head())
// Out:
// [DON QUIJOTE DE LA MANCHA]

// %%
println(leer.take(1))
// Out:
// [Lorg.apache.spark.sql.Row;@a0af3fc

// %%
println(leer.first())
// Out:
// [DON QUIJOTE DE LA MANCHA]
